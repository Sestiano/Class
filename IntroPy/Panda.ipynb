# %%
import pandas as pd 

#creating a dataframe from a dictionary
data = {
    'Subject' : ['A', 'B', 'C', 'D'],
    'Score' : [85, 90, 78, 92]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Subject  Score
# 0       A     85
# 1       B     90
# 2       C     78
# 3       D     92

# %%
# Load data from a CSV file
df = pd.read_csv('data.csv')

# %%
# Viewing the first few rows
print(df.head())
# Understanding the structure
print(df.info())
# Descriptive statistics
print(df.describe())
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
# Selecting a column
print(df['Calories_Burned'])
# Filtering rows based on a condition
high_scores = df[df['Calories_Burned'] > 1000]
print(high_scores)
# Out:
# 0      1313.0
# 1       883.0
# 2       677.0
# 3       532.0
# 4       556.0
#         ...
# 968    1364.0
# 969    1260.0
# 970     929.0
# 971     883.0
# 972     542.0
# Name: Calories_Burned, Length: 973, dtype: float64
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 5     56  Female         58.0        1.68      168      156           74
# 6     36    Male         70.3        1.72      174      169           73
# 12    57    Male        112.5        1.61      195      165           61
# 14    20    Male        117.7        1.81      196      161           54
# ..   ...     ...          ...         ...      ...      ...          ...
# 964   56  Female         64.2        1.69      190      137           61
# 966   23    Male         87.3        1.91      164      129           58
# 967   20    Male         55.0        1.60      172      168           67
# ...

# %%
#checking for missing values
print(df.isnull().sum())

#filling missing data
df['Calories_Burned'] = df ['Calories_Burned'].fillna(df['Calories_Burned'].mean())

#dropping rows with missing data
df = df.dropna()
# Out:
# Age                              0
# Gender                           0
# Weight (kg)                      0
# Height (m)                       0
# Max_BPM                          0
# Avg_BPM                          0
# Resting_BPM                      0
# Session_Duration (hours)         0
# Calories_Burned                  0
# Workout_Type                     0
# Fat_Percentage                   0
# Water_Intake (liters)            0
# Workout_Frequency (days/week)    0
# Experience_Level                 0
# BMI                              0
# dtype: int64

# %%
# Renaming columns
df.rename(columns={'Subject': 'Participant'}, inplace=True)
# Changing data types
df['Calories_Burned'] = df['Calories_Burned'].astype(int)
# Applying a function to a column
df['Calories_Burned'] = df['Calories_Burned'].apply(lambda x: x * 1.1) #increase scores by 10%

# %%
grouped = df.groupby('Gender')['Calories_Burned'].mean()
print('Printing Grouped')
print(grouped)
# Aggregating data
aggregated = df['Calories_Burned'].agg(['mean', 'sum', 'count'])
print('Printing Aggregated')
print(aggregated)
# Sorting data
sorted_df = df.sort_values(by='Calories_Burned', ascending=False)
print('Printing sorted')
print(sorted_df[['Gender', 'Calories_Burned', 'Age']])
# Out:
# Printing Grouped
# Gender
# Female     948.473810
# Male      1038.901566
# Name: Calories_Burned, dtype: float64
# Printing Aggregated
# mean        995.964645
# sum      969073.600000
# count       973.000000
# Name: Calories_Burned, dtype: float64
# Printing sorted
#      Gender  Calories_Burned  Age
# 910    Male           1961.3   32
# 712    Male           1942.6   19
# 511    Male           1897.5   39
# 124    Male           1871.1   26
# 90     Male           1856.8   25
# ..      ...              ...  ...
# 298    Male            366.3   50
# 569    Male            364.1   53
# 619  Female            363.0   25
# 742  Female            350.9   23
# 650  Female            333.3   47
#
# [973 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
# Basic line plot
df['Calories_Burned'].plot(kind='line')
plt.title('Calories_Burned')
plt.xlabel('Subject')
plt.ylabel('Calories_Burned')
plt.show()
# Histogram
df['Calories_Burned'].plot(kind='hist')
plt.title('Distribution of Calories_Burned')
plt.show()

# %%
# Sample DataFrame
data = {
'Subject': ['A', 'B', 'C', 'D'],
'Score': [85, 90, 78, 92],
'Age': [23, 21, 25, 22]
}
df = pd.DataFrame(data)
# Iterate through each record and transform it into a dictionary
for index, row in df.iterrows():
    record_dict = row.to_dict()
print(f"Record {index + 1} as a dictionary: {record_dict}")
# Out:
# Record 4 as a dictionary: {'Subject': 'D', 'Score': 92, 'Age': 22}
